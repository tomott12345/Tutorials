# %%
#Inspired / borrowed / stolen from: https://medium.com/@stallonejacob/time-series-forecast-a-basic-introduction-using-python-414fcb963000
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 8]

#Here we add some datetime and stats processing libraries. To test a time series stationarity, we'll use the Dickey Fuller test.

from datetime import datetime
from statsmodels.tsa.stattools import adfuller

# %%
#First, read in the data as a pandas dataframe
data = pd.read_csv('GLD.csv')

# %%
#check the top of the dataframe using 'head'
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-08-20  112.379997  112.739998  112.160004  112.690002  112.690002
# 1  2018-08-21  112.769997  113.099998  112.440002  113.019997  113.019997
# 2  2018-08-22  113.389999  113.489998  113.070000  113.269997  113.269997
# 3  2018-08-23  112.680000  112.879997  112.059998  112.199997  112.199997
# 4  2018-08-24  113.250000  114.419998  113.209999  114.160004  114.160004
#
#     Volume
# 0  5313400
# 1  5042400
# 2  6215600
# 3  5500100
# 4  9214700

# %%
#convert the Date column into datetime object

data['Date']=pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

#check datatype of index
data.index
# Out:
# DatetimeIndex(['2018-08-20', '2018-08-21', '2018-08-22', '2018-08-23',
#                '2018-08-24', '2018-08-27', '2018-08-28', '2018-08-29',
#                '2018-08-30', '2018-08-31',
#                ...
#                '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-10',
#                '2020-08-11', '2020-08-12', '2020-08-13', '2020-08-14',
#                '2020-08-17', '2020-08-18'],
#               dtype='datetime64[ns]', name='Date', length=503, freq=None)

# %%
#select a column for the time series:
ts = data['Close']
ts.head(10)
# Out:
# Date
# 2018-08-20    112.690002
# 2018-08-21    113.019997
# 2018-08-22    113.269997
# 2018-08-23    112.199997
# 2018-08-24    114.160004
# 2018-08-27    114.589996
# 2018-08-28    113.680000
# 2018-08-29    114.199997
# 2018-08-30    113.639999
# 2018-08-31    113.510002
# Name: Close, dtype: float64

# %%
#check what a plot of it looks like using matplotlib
plt.plot(ts)
plt.title('Stock Closing Price')
# Out:
# Text(0.5, 1.0, 'Stock Closing Price')

# %%
#thanks to Jacob for this handy stationarity function, saved me time writing it.
#There was a change in pandas on how to handle the rolling statistics and I updaed that in the function below

def test_stationarity(timeseries):
    
    #Determing rolling statistics. This was updated from the original post by Jacob
    rolmean = pd.Series(timeseries).rolling(window=12).mean()
    rolstd = pd.Series(timeseries).rolling(window=12).std()
    
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#check the time series stationarity for Close
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   1.165351
# p-value                          0.995738
# #Lags Used                       5.000000
# Number of Observations Used    497.000000
# Critical Value (1%)             -3.443576
# Critical Value (5%)             -2.867373
# Critical Value (10%)            -2.569877
# dtype: float64

# %% [markdown]
# ## This time series is NOT stationary
#
# What this means is that rolling mean is increasing but the standard deviation is flat or falling. Plus the test statistic (1.16) is greater than the Critical Values. No good, this is probably in a trend. Duh.

# %%
#Convert time series into a log series
ts_log = np.log(ts)

# %%
#Let's try the some moving average differences
#First we create a 12 day rolling moving average in Pandas
moving_avg = pd.Series(ts_log).rolling(window=12).mean()

# %%
#Let's check the plots, looks good so far
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
#Now some magic, we subtract the log prices from the moving average and check them out.
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(12)
# Out:
# Date
# 2018-08-20        NaN
# 2018-08-21        NaN
# 2018-08-22        NaN
# 2018-08-23        NaN
# 2018-08-24        NaN
# 2018-08-27        NaN
# 2018-08-28        NaN
# 2018-08-29        NaN
# 2018-08-30        NaN
# 2018-08-31        NaN
# 2018-09-04        NaN
# 2018-09-05   -0.00099
# Name: Close, dtype: float64

# %%
#Note, there's a lot of NaN's because of the subtraction of the moving average from the price, so we drop them inplace
ts_log_moving_avg_diff.dropna(inplace=True)
ts_log_moving_avg_diff.head(12)
# Out:
# Date
# 2018-09-05   -0.000990
# 2018-09-06    0.000323
# 2018-09-07   -0.002566
# 2018-09-10   -0.003184
# 2018-09-11   -0.003320
# 2018-09-12    0.005028
# 2018-09-13    0.002037
# 2018-09-14   -0.004004
# 2018-09-17    0.001634
# 2018-09-18    0.000283
# 2018-09-19    0.003883
# 2018-09-20    0.006319
# Name: Close, dtype: float64

# %%
#Now let's check stationarity. 
test_stationarity(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.729395e+00
# p-value                        6.654371e-07
# #Lags Used                     1.400000e+01
# Number of Observations Used    4.770000e+02
# Critical Value (1%)           -3.444134e+00
# Critical Value (5%)           -2.867618e+00
# Critical Value (10%)          -2.570008e+00
# dtype: float64

# %% [markdown]
# ## This is Stationary
#
# The test statistic is -5.72, it is smaller than than the 1% value of -3.4. Very nice. We are 99% confident that this is stationary with the data preprocessing we've done. Let's try a moving weighted average.

# %%
#Try EMWA
expweighted_avg = pd.DataFrame.ewm(ts_log, halflife=12).mean()
plt.plot(ts_log)
plt.plot(expweighted_avg, color='red')

# %%
# Subtract out the log values from the expweighte average and test stationary
ts_log_ewma_diff = ts_log - expweighted_avg
test_stationarity(ts_log_ewma_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.077223
# p-value                          0.001056
# #Lags Used                       5.000000
# Number of Observations Used    497.000000
# Critical Value (1%)             -3.443576
# Critical Value (5%)             -2.867373
# Critical Value (10%)            -2.569877
# dtype: float64

# %% [markdown]
# ## This IS stationary.
# Turns out that using an EWMA and substracting out the log creates a stationary time series. That is great!

# %%
#Let's try to make predictions. First we shift the time series back by 1 day.

ts_log_diff = ts_log - ts_log.shift()
ts_log_diff.dropna(inplace=True)


plt.plot(ts_log_diff)

#Then we test if it's still stationary.
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.178511e+01
# p-value                        1.013146e-21
# #Lags Used                     4.000000e+00
# Number of Observations Used    4.970000e+02
# Critical Value (1%)           -3.443576e+00
# Critical Value (5%)           -2.867373e+00
# Critical Value (10%)          -2.569877e+00
# dtype: float64

# %% [markdown]
# ## This is NOT Stationary!
# Turns out when you do the shift by one day, the GLD model isn't stationary, so it's probably in a trend. Let's check this out by decomposing the time series.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(ts_log, model="multiplicative", period=12)

# %%
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.subplot(411)
plt.plot(ts_log, label="Original")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label="Trend")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label="Seasonal")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label="Residuals")
plt.legend(loc='best')

# %% [markdown]
# ## This is in a Trend!
# There is strong seasonality and the

# %%
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.085534e+00
# p-value                        1.423238e-12
# #Lags Used                     1.500000e+01
# Number of Observations Used    4.750000e+02
# Critical Value (1%)           -3.444192e+00
# Critical Value (5%)           -2.867644e+00
# Critical Value (10%)          -2.570021e+00
# dtype: float64

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')
# Out:
# /Users/thomasott/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning

# %%
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
#ARIMA Model
model = ARIMA(ts_log, order=(2,1,2))
results_ARIMA = model.fit(disp=-1)
plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS %.4f' %sum(results_ARIMA.fittedvalues-ts_log_diff)**2)
# Out:
# /Users/thomasott/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/thomasott/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Text(0.5, 1.0, 'RSS 0.0000')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
predictions_ARIMA_diff.head()
# Out:
# Date
# 2018-08-21    0.001014
# 2018-08-22    0.001101
# 2018-08-23    0.001161
# 2018-08-24    0.000633
# 2018-08-27    0.001111
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_diff_cumsum.head()
# Out:
# Date
# 2018-08-21    0.001014
# 2018-08-22    0.002116
# 2018-08-23    0.003277
# 2018-08-24    0.003910
# 2018-08-27    0.005021
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(ts_log.iloc[0], index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Date
# 2018-08-20    4.724641
# 2018-08-21    4.725655
# 2018-08-22    4.726757
# 2018-08-23    4.727918
# 2018-08-24    4.728550
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f' % np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
# Out:
# Text(0.5, 1.0, 'RMSE: 10.4626')
